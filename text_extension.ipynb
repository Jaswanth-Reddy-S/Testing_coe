# %%
pip install transformers
# Out:
# ...
#      |████████████████████████████████| 2.2MB 12.0MB/s
# ...
#      |████████████████████████████████| 870kB 34.3MB/s
# ...
#      |████████████████████████████████| 3.3MB 38.1MB/s
# ...
#   Created wheel for sacremoses: filename=sacremoses-0.0.44-cp37-none-any.whl size=886084 sha256=61552ecdaef5cce85cad821210592f88bfa70a36ecf48cf0a51076c5b1dbe66d
#   Stored in directory: /root/.cache/pip/wheels/3e/fb/c0/13ab4d63d537658f448366744654323077c4d90069b6512f3c
# Successfully built sacremoses
# ...

# %%
pip list
# Out:
# Package                       Version
# ----------------------------- --------------
# absl-py                       0.12.0
# alabaster                     0.7.12
# albumentations                0.1.12
# altair                        4.1.0
# appdirs                       1.4.4
# argon2-cffi                   20.1.0
# astor                         0.8.1
# astropy                       4.2
# astunparse                    1.6.3
# async-generator               1.10
# atari-py                      0.2.6
# atomicwrites                  1.4.0
# attrs                         20.3.0
# audioread                     2.1.9
# autograd                      1.3
# Babel                         2.9.0
# backcall                      0.2.0
# beautifulsoup4                4.6.3
# bleach                        3.3.0
# blis                          0.4.1
# bokeh                         2.3.0
# Bottleneck                    1.3.2
# branca                        0.4.2
# bs4                           0.0.1
# ...

# %%
# !git clone https://github.com/huggingface/transformers
# Out:
# Cloning into 'transformers'...
# remote: Enumerating objects: 69270, done.
# remote: Total 69270 (delta 0), reused 0 (delta 0), pack-reused 69270
# Receiving objects: 100% (69270/69270), 52.63 MiB | 24.66 MiB/s, done.
# Resolving deltas: 100% (49084/49084), done.

# %%
pip install tensorboard

# %%
cd /content/transformers/examples/language-modeling
# Out:
# /content/transformers/examples/language-modeling

# %%
N=1
OUTPUT_DIR='/content/transformers/resultt'
TRAIN_FILE='/content/train.txt'
VALID_FILE='/content/valid.txt'

# %%
# !CUDA_VISIBLE_DEVICES=1 python /content/run_language_modeling.py \
--output_dir=$OUTPUT_DIR \
--model_type=gpt2 \
--model_name_or_path=gpt2 \
--do_train \
--train_data_file=$TRAIN_FILE \
--do_eval \
--eval_data_file=$VALID_FILE \
--per_device_train_batch_size=2 \
--per_device_eval_batch_size=2 \
--line_by_line \
--learning_rate 5e-5 \
--num_train_epochs=2
# Out:
# 2021-04-08 09:28:44.283354: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.11.0
# 04/08/2021 09:28:45 - WARNING - __main__ -   Process rank: -1, device: cpu, n_gpu: 0, distributed training: False, 16-bits training: False
# ...

# %%
cd /content/transformers/examples/text-generation
# Out:
# /content/transformers/examples/text-generation

# %%
K=50
# !CUDA_VISIBLE_DEVICES=$N python /content/run_generation.py \
--model_type gpt2 \
--model_name_or_path $OUTPUT_DIR \
--length 100 \
--prompt "<BOS>" \
--stop_token "<EOS>" \
--k $K \
--num_return_sequences 5
# Out:
# 04/08/2021 10:58:19 - INFO - __main__ -   Namespace(device=device(type='cpu'), k=50, length=100, model_name_or_path='/content/transformers/resultt', model_type='gpt2', n_gpu=0, no_cuda=False, num_return_sequences=5, p=0.9, padding_text='', prompt='<BOS>', repetition_penalty=1.0, seed=42, stop_token='<EOS>', temperature=1.0, xlm_language='')
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# === GENERATED SEQUENCE 1 ===
# 2021-04-08 10:58:34.082784: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.11.0
# <BOS>  How to Set Up a macOS Phone and Its Touchscreen on the Mac
# === GENERATED SEQUENCE 2 ===
# <BOS>  No, you can't buy an Apple Watch smart watch without going into the Apple Store.
# === GENERATED SEQUENCE 3 ===
# <BOS>  New features and features coming soon to iOS
# === GENERATED SEQUENCE 4 ===
# <BOS>  "What kind of life would you like for everyone?"
# === GENERATED SEQUENCE 5 ===
# ...

# %%
# !git clone https://github.com/uber-research/PPLM
# Out:
# Cloning into 'PPLM'...
# remote: Enumerating objects: 26, done.
# remote: Counting objects: 100% (26/26), done.
# remote: Compressing objects: 100% (26/26), done.
# remote: Total 276 (delta 11), reused 1 (delta 0), pack-reused 250
# Receiving objects: 100% (276/276), 2.43 MiB | 5.24 MiB/s, done.
# Resolving deltas: 100% (116/116), done.

# %%
cd PPLM/
# Out:
# /content/transformers/examples/text-generation/PPLM

# %%
pip install transformers==3.4.0
# Out:
# ...
#      |████████████████████████████████| 1.3MB 9.7MB/s
# ...
#      |████████████████████████████████| 1.2MB 37.9MB/s
# ...
#      |████████████████████████████████| 2.9MB 38.0MB/s
# ...
#   Found existing installation: tokenizers 0.10.2
#     Uninstalling tokenizers-0.10.2:
#       Successfully uninstalled tokenizers-0.10.2
#   Found existing installation: transformers 4.5.0
#     Uninstalling transformers-4.5.0:
#       Successfully uninstalled transformers-4.5.0
# ...

# %%
# !CUDA_VISIBLE_DEVICES=$1 python /content/transformers/examples/text-generation/PPLM/run_pplm.py -B /content/keywords.txt --pretrained_model $OUTPUT_DIR --cond_text="The novel" --num_samples=4 --length=150 --stepsize=0.03 --num_iterations=3 --window_length=5 --gamma=1.5 --gm_scale=0.95 --kl_scale=0.01 --colorama --verbosity='regular' --sample
# Out:
# 2021-04-08 11:06:05.075671: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.11.0
# = Prefix of sentence =
# <BOS> The novel
#
# Using PPLM-BoW
# /usr/local/lib/python3.7/dist-packages/transformers/modeling_gpt2.py:759: FutureWarning: The `past` argument is deprecated and will be removed in a future version, use `past_key_values` instead.
#   FutureWarning,
# <BOS> The novel and
# <BOS> The novel and underrated
# <BOS> The novel and underrated Apple
# <BOS> The novel and underrated Apple Watch
# <BOS> The novel and underrated Apple Watch
# <BOS> The novel and underrated Apple Watch  <EOS>
# <BOS> The novel and underrated Apple Watch  <EOS> �
# <BOS> The novel and underrated Apple Watch  <EOS> 
# <BOS> The novel and underrated Apple Watch  <EOS> s
# <BOS> The novel and underrated Apple Watch  <EOS> s
# <BOS> The novel and underrated Apple Watch  <EOS> s  <EOS>
# ...

# %%
# !CUDA_VISIBLE_DEVICES=$1 python /content/transformers/examples/text-generation/PPLM/run_pplm.py -B /content/keywords.txt --pretrained_model $OUTPUT_DIR --cond_text="The novel" --num_samples=4 --length=150 --stepsize=0.03 --num_iterations=3 --window_length=5 --gamma=1.5 --gm_scale=0.95 --kl_scale=0.01 --colorama --verbosity='regular' --sample --save_path="/content/transformers/examples/final output/romance.txt"
# Out:
# 2021-04-08 11:28:32.264341: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.11.0
# = Prefix of sentence =
# <BOS> The novel
#
# Using PPLM-BoW
# /usr/local/lib/python3.7/dist-packages/transformers/modeling_gpt2.py:759: FutureWarning: The `past` argument is deprecated and will be removed in a future version, use `past_key_values` instead.
#   FutureWarning,
# <BOS> The novel and
# <BOS> The novel and underrated
# <BOS> The novel and underrated Apple
# <BOS> The novel and underrated Apple Watch
# <BOS> The novel and underrated Apple Watch
# <BOS> The novel and underrated Apple Watch  <EOS>
# <BOS> The novel and underrated Apple Watch  <EOS> �
# <BOS> The novel and underrated Apple Watch  <EOS> 
# <BOS> The novel and underrated Apple Watch  <EOS> s
# <BOS> The novel and underrated Apple Watch  <EOS> s
# <BOS> The novel and underrated Apple Watch  <EOS> s  <EOS>
# ...

# %%
a='/content/transformers/resultt/checkpoint-1000'

# %%
# !CUDA_VISIBLE_DEVICES=$1 python /content/transformers/examples/text-generation/PPLM/run_pplm.py -B /content/keywords.txt --pretrained_model $a --cond_text="The novel" --num_samples=4 --length=150 --stepsize=0.03 --num_iterations=3 --window_length=5 --gamma=1.5 --gm_scale=0.95 --kl_scale=0.01 --colorama --verbosity='regular' --sample
# Out:
# 2021-04-08 11:43:54.155076: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.11.0
# Traceback (most recent call last):
#   File "/content/transformers/examples/text-generation/PPLM/run_pplm.py", line 947, in <module>
#     run_pplm_example(**vars(args))
#   File "/content/transformers/examples/text-generation/PPLM/run_pplm.py", line 739, in run_pplm_example
#     tokenizer = GPT2Tokenizer.from_pretrained(pretrained_model)
#   File "/usr/local/lib/python3.7/dist-packages/transformers/tokenization_utils_base.py", line 1591, in from_pretrained
#     list(cls.vocab_files_names.values()),
# ...
